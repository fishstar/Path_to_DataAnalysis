# %% [markdown]
# # Interactive Data Visualization with Bokeh(4) - Building interactive apps with Bokeh

# %%
from ipywidgets import interact
from bokeh.io import output_notebook, push_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d90398f1-00e2-4cfd-a5dc-e1a7c579c527">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ##  Introducing the Bokeh
#
# ### Using the current document
#
# Let's get started with building an interactive Bokeh app. This typically begins with importing the curdoc, or "current document", function from bokeh.io. This current document will eventually hold all the plots, controls, and layouts that you create. Your job in this exercise is to use this function to add a single plot to your application.
#
# In the video, Bryan described the process for running a Bokeh app using the bokeh serve command line tool. In this chapter and the one that follows, the DataCamp environment does this for you behind the scenes. Notice that your code is part of a script.py file. When you hit 'Submit Answer', you'll see in the IPython Shell that we call bokeh serve script.py for you.
#
# Remember, as in the previous chapters, that there are different options available for you to interact with your plots, and as before, you may have to scroll down to view the lower portion of the plots.

# %%
# Perform necessary imports
from bokeh.io import curdoc, show
from bokeh.plotting import figure

# Create a new plot: plot
plot = figure()

# Add a line to the plot
plot.line([1,2,3,4,5], [2,5,4,6,7])

# Add the plot to the current document
# curdoc().add_root(plot)

show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a72f4e64-b07e-4a9f-99c0-a20b4ff81e1f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a72f4e64-b07e-4a9f-99c0-a20b4ff81e1f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a72f4e64-b07e-4a9f-99c0-a20b4ff81e1f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a72f4e64-b07e-4a9f-99c0-a20b4ff81e1f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6215db4b-67e3-4a9c-adcf-d8b0ae92fbf1":{"roots":{"references":[{"attributes":{},"id":"b42d7dac-89e3-4eb0-a114-e77f20724c27","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"fa9cd131-97ae-423f-83ab-a1365852d2a6","type":"ColumnDataSource"},"glyph":{"id":"5705cdc6-3602-406b-abed-020b05dc51a7","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"78d57632-7c86-448e-8315-a365a0a547e3","type":"Line"},"selection_glyph":null},"id":"4ab01405-59e1-47ff-901f-90d1d0837e86","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"78d57632-7c86-448e-8315-a365a0a547e3","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"17798e80-e1c8-4ada-b8ce-cfd4eff7e0cb","type":"BoxAnnotation"},{"attributes":{},"id":"f26b4506-244b-438a-9fce-219b7d84bcc2","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5],"y":[2,5,4,6,7]}},"id":"fa9cd131-97ae-423f-83ab-a1365852d2a6","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"f09d6480-a8c5-43ad-b51f-d9f10965c11e","type":"LinearAxis"}],"left":[{"id":"c11e42bf-224f-4357-80c3-9171b0a7e79e","type":"LinearAxis"}],"renderers":[{"id":"f09d6480-a8c5-43ad-b51f-d9f10965c11e","type":"LinearAxis"},{"id":"22774ab6-5f08-4790-9ca9-820b577937a7","type":"Grid"},{"id":"c11e42bf-224f-4357-80c3-9171b0a7e79e","type":"LinearAxis"},{"id":"3d7156aa-4b4f-4e93-931c-017ea4c714cd","type":"Grid"},{"id":"17798e80-e1c8-4ada-b8ce-cfd4eff7e0cb","type":"BoxAnnotation"},{"id":"4ab01405-59e1-47ff-901f-90d1d0837e86","type":"GlyphRenderer"}],"title":{"id":"0e1a39fc-225c-413c-8255-0f62f510793d","type":"Title"},"tool_events":{"id":"f26b4506-244b-438a-9fce-219b7d84bcc2","type":"ToolEvents"},"toolbar":{"id":"684ce970-8b8c-4d3d-a7d4-09a9a97159b5","type":"Toolbar"},"x_range":{"id":"d564a531-fea4-4b2b-b8c3-0040db0beacc","type":"DataRange1d"},"y_range":{"id":"ea456b66-930d-4c36-904a-4bf92703e1c2","type":"DataRange1d"}},"id":"3e63fb8d-56f3-4c06-9db2-31f231bce788","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"1c7fdc1b-c55b-40bd-b283-050e6147e577","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3e63fb8d-56f3-4c06-9db2-31f231bce788","subtype":"Figure","type":"Plot"},"ticker":{"id":"2afdf4bf-6d88-49e3-b4ba-9f69ce4436d7","type":"BasicTicker"}},"id":"22774ab6-5f08-4790-9ca9-820b577937a7","type":"Grid"},{"attributes":{"callback":null},"id":"d564a531-fea4-4b2b-b8c3-0040db0beacc","type":"DataRange1d"},{"attributes":{"formatter":{"id":"b42d7dac-89e3-4eb0-a114-e77f20724c27","type":"BasicTickFormatter"},"plot":{"id":"3e63fb8d-56f3-4c06-9db2-31f231bce788","subtype":"Figure","type":"Plot"},"ticker":{"id":"d17f8983-0d3c-4742-a4b2-3bb5754ba1e7","type":"BasicTicker"}},"id":"c11e42bf-224f-4357-80c3-9171b0a7e79e","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8695cd35-706f-4f44-93d1-0c96763eaa59","type":"PanTool"},{"id":"02225487-0963-4fca-b0db-9b3c91d25332","type":"WheelZoomTool"},{"id":"2604f4fd-bd73-4579-ab8c-33d6b223493c","type":"BoxZoomTool"},{"id":"af0be7bd-69d6-4c54-aef4-fb59825ab2ed","type":"SaveTool"},{"id":"aff94004-38e4-4e91-afd8-cb9ba2e6159a","type":"ResetTool"},{"id":"6e52b283-157a-4bd7-b78a-08e273320d1f","type":"HelpTool"}]},"id":"684ce970-8b8c-4d3d-a7d4-09a9a97159b5","type":"Toolbar"},{"attributes":{},"id":"d17f8983-0d3c-4742-a4b2-3bb5754ba1e7","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"0e1a39fc-225c-413c-8255-0f62f510793d","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"3e63fb8d-56f3-4c06-9db2-31f231bce788","subtype":"Figure","type":"Plot"},"ticker":{ ...

# %% [markdown]
# ### Add a single slider
#
# In the previous exercise, you added a single plot to the "current document" of your application. In this exercise, you'll practice adding a layout to your current document.
#
# Your job here is to create a single slider, use it to create a widgetbox layout, and then add this layout to the current document.
#
# The slider you create here cannot be used for much, but in the later exercises, you'll use it to update your plots!

# %%
# Perform the necessary imports
from bokeh.io import curdoc
from bokeh.layouts import widgetbox
from bokeh.models import Slider

# Create a slider: slider
slider = Slider(title='my slider', start=0, end=10, step=0.1, value=2)

# Create a widgetbox layout: layout
layout = widgetbox(slider)

# Add the layout to the current document
# curdoc().add_root(layout)

show(layout)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="197b5bba-2749-4dfd-9c66-edffc159141f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("197b5bba-2749-4dfd-9c66-edffc159141f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("197b5bba-2749-4dfd-9c66-edffc159141f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '197b5bba-2749-4dfd-9c66-edffc159141f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"968c5ce6-1756-4790-8db3-3dfbd4922423":{"roots":{"references":[{"attributes":{"children":[{"id":"05606122-bb0b-43d5-bc3b-aeea6dfb7097","type":"Slider"}]},"id":"ae2fac6a-1683-4f8c-9c14-ad4553abb0c0","type":"WidgetBox"},{"attributes":{"callback":null,"end":10,"title":"my slider","value":2},"id":"05606122-bb0b-43d5-bc3b-aeea6dfb7097","type":"Slider"}],"root_ids":["ae2fac6a-1683-4f8c-9c14-ad4553abb0c0"]},"title":"Bokeh Application","version":"0.12.5"}};
#             var render_items = [{"docid":"968c5ce6-1756-4790-8db3-3dfbd4922423","elementid":"197b5bba-2749-4dfd-9c66-edffc159141f","modelid":"ae2fac6a-1683-4f8c-9c14-ad4553abb0c0"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         window._bokeh_failed_load = true;
#       } else if (force !== true) {
#         var cell = $(document.getElementById("197b5bba-2749-4dfd-9c66-edffc159141f")).parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>

# %% [markdown]
# ### Multiple sliders in one document
#
# Having added a single slider in a widgetbox layout to your current document, you'll now add multiple sliders into the current document.
#
# Your job in this exercise is to create two sliders, add them to a widgetbox layout, and then add the layout into the current document.

# %%
# Perform necessary imports
from bokeh.io import curdoc
from bokeh.layouts import widgetbox
from bokeh.models import Slider

# Create first slider: slider1
slider1 = Slider(title='slider1', start=0, end=10, step=0.1, value=2)

# Create second slider: slider2
slider2 = Slider(title='slider2', start=10, end=100, step=1, value=20)

# Add slider1 and slider2 to a widgetbox
layout = widgetbox(slider1, slider2)

# Add the layout to the current document
#curdoc().add_root(layout)

show(layout)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e35d8e60-c958-40be-a067-7735eb823eea"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e35d8e60-c958-40be-a067-7735eb823eea");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e35d8e60-c958-40be-a067-7735eb823eea");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e35d8e60-c958-40be-a067-7735eb823eea' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"90e466a3-7041-4ed9-a3c2-4dfaeb4c7bff":{"roots":{"references":[{"attributes":{"callback":null,"end":100,"start":10,"step":1,"title":"slider2","value":20},"id":"64c67a2c-bf5b-4b71-8740-a41771c5e755","type":"Slider"},{"attributes":{"callback":null,"end":10,"title":"slider1","value":2},"id":"c7a88ed1-1665-492c-8a94-e5e86a68f8c8","type":"Slider"},{"attributes":{"children":[{"id":"c7a88ed1-1665-492c-8a94-e5e86a68f8c8","type":"Slider"},{"id":"64c67a2c-bf5b-4b71-8740-a41771c5e755","type":"Slider"}]},"id":"e13e8301-54ba-403e-a017-c8d3f43c1799","type":"WidgetBox"}],"root_ids":["e13e8301-54ba-403e-a017-c8d3f43c1799"]},"title":"Bokeh Application","version":"0.12.5"}};
#             var render_items = [{"docid":"90e466a3-7041-4ed9-a3c2-4dfaeb4c7bff","elementid":"e35d8e60-c958-40be-a067-7735eb823eea","modelid":"e13e8301-54ba-403e-a017-c8d3f43c1799"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         window._bokeh_failed_load = true;
#       } else if (force !== true) {
#         var cell = $(document.getElementById("e35d8e60-c958-40be-a067-7735eb823eea")).parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>

# %% [markdown]
# ## Connecting sliders to plots

# %%
import numpy as np
from bokeh.plotting import ColumnDataSource, figure

x = np.linspace(0.3, 10, 200)
y = np.sin(1/x)

# Add a line to the plot
plot = figure()
r = plot.line(x,y)

def update(scale=1):
    r.data_source.data['y'] = np.sin(scale/x)
    push_notebook()
    
show(plot, notebook_handle=True)
interact(update, scale=(1,10))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a04c81d9-144d-4fa2-bb3c-eec93416516b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a04c81d9-144d-4fa2-bb3c-eec93416516b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("d71ab4a8-5d23-43a9-9c5b-fd551013a1c1", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a04c81d9-144d-4fa2-bb3c-eec93416516b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a04c81d9-144d-4fa2-bb3c-eec93416516b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"afd0d8a9-d7de-45cf-beb9-f7753262a05c":{"roots":{"references":[{"attributes":{"data_source":{"id":"cf14cf6d-4080-488e-b495-a97cfc566b78","type":"ColumnDataSource"},"glyph":{"id":"42131d48-1a31-4d2c-a829-eea144d570c5","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3572088b-6252-4265-a536-dd6613835ae6","type":"Line"},"selection_glyph":null},"id":"951eea9e-9f30-4715-b161-f50ca02cec42","type":"GlyphRenderer"},{"attributes":{},"id":"78825378-f17c-4cec-b76a-65d1d8d981d5","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"228e1212-436c-4a85-a0db-f72ae6c3d9c0","subtype":"Figure","type":"Plot"}},"id":"1d07382a-4c0a-4592-94fc-eeed796ce21b","type":"PanTool"},{"attributes":{"below":[{"id":"c5dd4014-538d-4677-a754-d1b5cedf41b2","type":"LinearAxis"}],"left":[{"id":"c47f9bf4-843b-444d-8a8b-b03dc9acf914","type":"LinearAxis"}],"renderers":[{"id":"c5dd4014-538d-4677-a754-d1b5cedf41b2","type":"LinearAxis"},{"id":"c77528be-a0d7-40d7-997d-6ee6de2423ef","type":"Grid"},{"id":"c47f9bf4-843b-444d-8a8b-b03dc9acf914","type":"LinearAxis"},{"id":"fbaab705-a358-4e3c-a7ae-c8a2976f25f7","type":"Grid"},{"id":"c95cc4c1-bb06-4f20-9506-ed09efbdadd6","type":"BoxAnnotation"},{"id":"951eea9e-9f30-4715-b161-f50ca02cec42","type":"GlyphRenderer"}],"title":{"id":"31993d95-5994-467d-96d2-ad7a6ec77471","type":"Title"},"tool_events":{"id":"8ae5b44d-be6e-4cd5-9de9-a2a0ea91dd13","type":"ToolEvents"},"toolbar":{"id":"0d713e63-98ee-4c9c-b895-33542abef9c3","type":"Toolbar"},"x_range":{"id":"574e871c-3c67-4e14-b210-73ed59d10cde","type":"DataRange1d"},"y_range":{"id":"93dd4553-cf37-4942-bb14-43cdde03de38","type":"DataRange1d"}},"id":"228e1212-436c-4a85-a0db-f72ae6c3d9c0","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c95cc4c1-bb06-4f20-9506-ed09efbdadd6","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"93dd4553-cf37-4942-bb14-43cdde03de38","type":"DataRange1d"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"42131d48-1a31-4d2c-a829-eea144d570c5","type":"Line"},{"attributes":{"plot":{"id":"228e1212-436c-4a85-a0db-f72ae6c3d9c0","subtype":"Figure","type":"Plot"},"ticker":{"id":"0cfc98c9-c3d6-45f9-b8f9-e85113b139e0","type":"BasicTicker"}},"id":"c77528be-a0d7-40d7-997d-6ee6de2423ef","type":"Grid"},{"attributes":{},"id":"0cfc98c9-c3d6-45f9-b8f9-e85113b139e0","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"31993d95-5994-467d-96d2-ad7a6ec77471","type":"Title"},{"attributes":{},"id":"2d04e11a-87ef-450f-9a0b-e46ed23d73ca","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"228e1212-436c-4a85-a0db-f72ae6c3d9c0","subtype":"Figure","type":"Plot"}},"id":"d183d400-3a19-4e82-b7a8-4f68deb2a7f8","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3572088b-6252-4265-a536-dd6613835ae6","type":"Line"},{"attributes":{},"id":"03769725-6e3a-42b6-9984-483748ccdb74","type":"BasicTicker"},{"attributes":{"formatter":{"id":"2d04e11a-87ef-450f-9a0b-e46ed23d73ca","type":"BasicTickFormatter"},"plot":{"id":"228e1212-436c-4a85-a0db-f72ae6c3d9c0","subtype":"Figure","type":"Plot"},"ticker":{"id":"03769725-6e3a-42b6-9984-483748ccdb74","type":"BasicTicker"}},"id":"c47f9bf4-843b-444d-8a8b-b03dc9acf914","type":"LinearAxis"},{"attributes":{},"id":"8ae5b44d-be6e-4cd5-9de9-a2a0ea91dd13","type":"ToolEvents"},{"attributes":{"plot":{"id":"228e1212-436c-4a85-a0db-f72ae6c3d9c0","subtype":"Figure","type":"Plot"}},"id":"5077291a-be01-4abc-80d4-7987dc319ee6","type":"SaveTool"},{"attributes":{"callback":null},"id":"574e871c-3c67-4e14-b210-73ed59d10cde","type":"DataRange1d"},{"attributes": ...
# <function __main__.update>

# %% [markdown]
# ## Updating plots from dropdowns

# %%
import pandas as pd
df = pd.read_csv('literacy_birth_rate.csv')
df = df.rename(columns={'Country ':'Country', 'female literacy':'female_literacy'})
df.female_literacy = pd.to_numeric(df.female_literacy, errors='coerce')
df.fertility = pd.to_numeric(df.fertility, errors='coerce')
df = df.dropna()
df.head()
# Out:
#      Country Continent  female_literacy  fertility    population
# 0      Chine       ASI             90.5      1.769  1.324655e+09
# 1       Inde       ASI             50.8      2.682  1.139965e+09
# 2        USA       NAM             99.0      2.077  3.040600e+08
# 3  Indonésie       ASI             88.8      2.132  2.273451e+08
# 4     Brésil       LAT             90.2      1.827  1.919715e+08

# %%
# Create a new plot: plot
plot = figure()

# Add circles to the plot
r = plot.circle(x=df.fertility, y=df.female_literacy)

# Define a callback function: update_plot
def update_plot(distribution):
    # If the distribution Selection is 'female_literacy', update 'y' to female_literacy
    if distribution == 'female_literacy': 
        r.data_source.data['y'] = df.female_literacy
        
    # Else, update 'y' to population
    else:
        r.data_source.data['y'] = df.population
        
    push_notebook()
    

show(plot, notebook_handle=True)

interact(update_plot, distribution=['female_literacy', 'population'])
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0a446c22-96fa-4a89-aa2e-3330e743260c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0a446c22-96fa-4a89-aa2e-3330e743260c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("45064593-9858-42c7-8754-892ca0fe899d", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0a446c22-96fa-4a89-aa2e-3330e743260c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0a446c22-96fa-4a89-aa2e-3330e743260c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c4709236-ac59-4a7f-b3be-6a2109bce7b7":{"roots":{"references":[{"attributes":{"plot":{"id":"545ea137-0af0-435f-954c-a06291ce8e26","subtype":"Figure","type":"Plot"}},"id":"80a43b5c-4b50-4b15-8231-ec08fe57537d","type":"PanTool"},{"attributes":{},"id":"d1b4b1c0-1c21-4989-b7ae-1fef1f566604","type":"BasicTicker"},{"attributes":{"formatter":{"id":"39d07b5f-56d5-4d4a-b4b4-25faa9d3b768","type":"BasicTickFormatter"},"plot":{"id":"545ea137-0af0-435f-954c-a06291ce8e26","subtype":"Figure","type":"Plot"},"ticker":{"id":"98a6f572-b833-4656-8874-b3ef13f78678","type":"BasicTicker"}},"id":"14546d68-490a-4022-9527-355601d2e4c6","type":"LinearAxis"},{"attributes":{},"id":"cd8b611e-8490-43de-8086-6bcc0c1c00ed","type":"BasicTickFormatter"},{"attributes":{},"id":"39d07b5f-56d5-4d4a-b4b4-25faa9d3b768","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[162]},"y":{"__ndarray__":"...","dtype":"float64","shape":[162]}}},"id":"f7e29dfd-4af6-4ae7-8448-3950fbe60426","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"14546d68-490a-4022-9527-355601d2e4c6","type":"LinearAxis"}],"left":[{"id":"859d60fa-f15d-43b1-aff6-f5971e1f4cd8","type":"LinearAxis"}],"renderers":[{"id":"14546d68-490a-4022-9527-355601d2e4c6","type":"LinearAxis"},{"id":"87559d94-8de0-4742-821c-b9d63fe30a2e","type":"Grid"},{"id":"859d60fa-f15d-43b1-aff6-f5971e1f4cd8","type":"LinearAxis"},{"id":"fe99dd8f-ef79-4ebf-8dde-87124228f48f","type":"Grid"},{"id":"b26c861d-356c-4db5-992d-8ffa58f67011","type":"BoxAnnotation"},{"id":"29512690-91b0-4cb5-b85b-65e7cd726ccc","type":"GlyphRenderer"}],"title":{"id":"5d3f3cdc-fadd-4238-b3f7-d0d7a93aa2a4","type":"Title"},"tool_events":{"id":"35aaee77-863a-4ee6-99e5-b270e589a6c3","type":"ToolEvents"},"toolbar":{"id":"9c4481bd-24c1-4328-ad8f-32fbb6b8c989","type":"Toolbar"},"x_range":{"id":"31a8a7e0-5ff3-4ccd-883a-59dab8bae90a","type":"DataRange1d"},"y_range":{"id":"9cb2e25f-bacd-4657-b958-291ca785b2ba","type":"DataRange1d"}},"id":"545ea137-0af0-435f-954c-a06291ce8e26","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"264b0ff4-9d9e-4274-85f1-d4ce232f1d26","type":"Circle"},{"attributes":{"plot":{"id":"545ea137-0af0-435f-954c-a06291ce8e26","subtype":"Figure","type":"Plot"}},"id":"322016c1-7075-49e8-b5b8-d979433cbc6f","type":"HelpTool"},{"attributes":{"overlay":{"id":"b26c861d-356c-4db5-992d-8ffa58f67011","type":"BoxAnnotation"},"plot":{"id":"545ea137-0af0-435f-954c-a06291ce8e26","subtype":"Figure","type":"Plot"}},"id":"d489b23d-f894-4500-b46f-0b09ae5511c8","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":""},"id":"5d3f3cdc-fadd-4238-b3f7-d0d7a93aa2a4","type":"Title"},{"attributes":{},"id":"98a6f572-b833-4656-8874-b3ef13f78678","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b26c861d-356c-4db5-992d-8ffa58f67011","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"9cb2e25f-bacd-4657-b958-291ca785b2ba","type":"DataRange1d"},{"attributes":{"plot":{"id":"545ea137-0af0-435f-954c-a06291ce8e26","subtype":"Figure","type":"Plot"}},"id":"f95c2328-28ac-4364-8f3b-30fb939fbb0e","type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"545ea137-0af0-435f-954c-a06291ce8e26","subtype":"Figure","type":"Plot"},"ticker":{"id":"d1b4b1c0-1c21-4989-b7ae-1fef1f566604","type":"BasicTicker"}},"id":"fe99dd8f-ef79-4ebf-8dde-87124228f48f","type":"Grid"},{"attributes":{"plot":{"id":"545ea137-0af0-435f-954c-a06291ce8e26","subtype":"Figure","type":"Plot"},"ticker":{"id":"98a6f572-b833-4656-8874-b3ef1 ...
# <function __main__.update_plot>

# %% [markdown]
# ### Synchronize two dropdowns
#
# Here, you'll practice using a dropdown callback to update another dropdown's options. This will allow you to customize your applications even further and is a powerful addition to your toolbox.
#
# Your job in this exercise is to create two dropdown select widgets and then define a callback such that one dropdown is used to update the other dropdown.
#
# All modules necessary have been imported.

# %%
from bokeh.io import curdoc
from bokeh.layouts import widgetbox
from bokeh.models import Select

# Create two dropdown Select widgets: select1, select2
select1 = Select(title='First', options=['A', 'B'], value='A')
select2 = Select(title='Second', options=['1', '2', '3'], value='1')

# Define a callback function: callback
def callback(attr, old, new):
    # If select1 is 'A' 
    if select1.value == 'A':
        # Set select2 options to ['1', '2', '3']
        select2.options = ['1', '2', '3']

        # Set select2 value to '1'
        select2.value = '1'
    else:
        # Set select2 options to ['100', '200', '300']
        select2.options = ['100', '200', '300']

        # Set select2 value to '100'
        select2.value = '100'
        
    push_notebook()

# Attach the callback to the 'value' property of select1
select1.on_change('value', callback)

# Create layout and add to current document
layout = widgetbox(select1, select2)
curdoc().add_root(layout)

# %% [markdown]
# ** note: Run single module apps at the shell or Windows command prompt:**
# ```
# bokeh serve --show myapp.py
# ```

# %% [markdown]
# ## Buttons
#
# ### Button styles
#
# You can also get really creative with your Button widgets.
#
# In this exercise, you'll practice using CheckboxGroup, RadioGroup, and Toggle to add multiple Button widgets with different styles.
#
# curdoc and widgetbox have already been imported for you.

# %%
# Import CheckboxGroup, RadioGroup, Toggle from bokeh.models
from bokeh.models import CheckboxGroup, RadioGroup, Toggle

# Add a Toggle: toggle
toggle = Toggle(button_type='success', label='Toggle button')

# Add a CheckboxGroup: checkbox
checkbox = CheckboxGroup(labels=['Option 1', 'Option 2', 'Option 3'])

# Add a RadioGroup: radio
radio = RadioGroup(labels=['Option 1', 'Option 2', 'Option 3'])

# Add widgetbox(toggle, checkbox, radio) to the current document
#curdoc().add_root(widgetbox(toggle, checkbox, radio))

show(widgetbox(toggle, checkbox, radio))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f230f15d-0702-40cf-a96e-cbb9446696d3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f230f15d-0702-40cf-a96e-cbb9446696d3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f230f15d-0702-40cf-a96e-cbb9446696d3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f230f15d-0702-40cf-a96e-cbb9446696d3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f16613cd-e1d8-46cb-b905-d093ce16655f":{"roots":{"references":[{"attributes":{"callback":null,"labels":["Option 1","Option 2","Option 3"]},"id":"8493de8d-55f9-4cb2-9482-48600823019f","type":"CheckboxGroup"},{"attributes":{"callback":null,"labels":["Option 1","Option 2","Option 3"]},"id":"9ebf7331-116c-477d-9f6c-50d451e626ef","type":"RadioGroup"},{"attributes":{"children":[{"id":"e157416d-d45a-4bc0-91d1-61c3063aacc2","type":"Toggle"},{"id":"8493de8d-55f9-4cb2-9482-48600823019f","type":"CheckboxGroup"},{"id":"9ebf7331-116c-477d-9f6c-50d451e626ef","type":"RadioGroup"}]},"id":"37629bf5-8f79-4923-8a95-3d30d5141aa3","type":"WidgetBox"},{"attributes":{"button_type":"success","callback":null,"icon":null,"label":"Toggle button"},"id":"e157416d-d45a-4bc0-91d1-61c3063aacc2","type":"Toggle"}],"root_ids":["37629bf5-8f79-4923-8a95-3d30d5141aa3"]},"title":"Bokeh Application","version":"0.12.5"}};
#             var render_items = [{"docid":"f16613cd-e1d8-46cb-b905-d093ce16655f","elementid":"f230f15d-0702-40cf-a96e-cbb9446696d3","modelid":"37629bf5-8f79-4923-8a95-3d30d5141aa3"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         window._bokeh_failed_load = true;
#       } else if (force !== true) {
#         var cell = $(document.getElementById("f230f15d-0702-40cf-a96e-cbb9446696d3")).parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>
