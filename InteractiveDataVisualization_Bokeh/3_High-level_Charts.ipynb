# %% [markdown]
# # Interactive Data Visualization with Bokeh(3) - High-level Charts

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="27bf9160-28da-49c4-962b-15dcbfb767e9">Loading BokehJS ...</span>
#     </div>

# %%
import pandas as pd
df = pd.read_csv('literacy_birth_rate.csv')
df = df.rename(columns={'Country ':'Country', 'female literacy':'female_literacy'})
df.female_literacy = pd.to_numeric(df.female_literacy, errors='coerce')
df.fertility = pd.to_numeric(df.fertility, errors='coerce')
df = df.dropna()
df.head()
# Out:
#      Country Continent  female_literacy  fertility    population
# 0      Chine       ASI             90.5      1.769  1.324655e+09
# 1       Inde       ASI             50.8      2.682  1.139965e+09
# 2        USA       NAM             99.0      2.077  3.040600e+08
# 3  Indonésie       ASI             88.8      2.132  2.273451e+08
# 4     Brésil       LAT             90.2      1.827  1.919715e+08

# %% [markdown]
# ## Histograms
#
# ### A basic histogram
#
# Create a simple histogram with the Histogram() function. Again we'll use the fertility data set to plot the distribution of female literacy around the world.
#
# As in the previous two chapters, you can interact with the figures you create in this chapter as well, and you may have to scroll down to view the lower portion of some of them.

# %%
# Import Histogram, output_file, and show from bokeh.charts
from bokeh.charts import Histogram, output_file, show

# Make a Histogram: p
p = Histogram(df, 'female_literacy', title='Female Literacy')

# Set the x axis label
p.xaxis.axis_label = 'literacy'

# Set the y axis label
p.yaxis.axis_label = 'count'

# Specify the name of the output_file and show the result
output_file('histogram.html')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b26e6bce-6af4-4ce2-8f22-06980d26f0b4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b26e6bce-6af4-4ce2-8f22-06980d26f0b4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b26e6bce-6af4-4ce2-8f22-06980d26f0b4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b26e6bce-6af4-4ce2-8f22-06980d26f0b4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7ba35bb4-6a71-48df-b83a-33ddbaeb6656":{"roots":{"references":[{"attributes":{},"id":"f78f155f-2a36-4ac5-952a-48c6b4d3e8c5","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c1c4c77b-5030-4712-813f-32b6a5feb4b3","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(56.300000, 67.225000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[13.0],"label":["(56.300000, 67.225000]"],"line_alpha":[1.0],"line_color":["black"],"width":[10.92499999999999],"x":["61.762499999999996"],"y":[6.5]}},"id":"1a14057b-fedb-4375-a92a-fab39ee1ae90","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"1a14057b-fedb-4375-a92a-fab39ee1ae90","type":"ColumnDataSource"},"glyph":{"id":"d8c6aa06-702e-401b-9b59-1a7ec5e8ff39","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"2e3ee50c-57b4-45ec-902a-574b90bfcda0","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(67.225000, 78.150000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[9.0],"label":["(67.225000, 78.150000]"],"line_alpha":[1.0],"line_color":["black"],"width":[10.925000000000011],"x":["72.6875"],"y":[4.5]}},"id":"5c45426f-6332-480c-a0ed-43d5eb310a6c","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0fdd41c2-99fd-4a07-9194-f0b91af5f49f","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(78.150000, 89.075000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[25.0],"label":["(78.150000, 89.075000]"],"line_alpha":[1.0],"line_color":["black"],"width":[10.924999999999997],"x":["83.61250000000001"],"y":[12.5]}},"id":"d82fcc29-051b-4161-bef4-b6d40ab20b47","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"4e4eb96e-3172-44d5-b3ef-e856aae4f928","subtype":"Chart","type":"Plot"}},"id":"1dec6145-1113-47bf-83a1-6ec3714c2ef0","type":"HelpTool"},{"attributes":{"data_source":{"id":"5c45426f-6332-480c-a0ed-43d5eb310a6c","type":"ColumnDataSource"},"glyph":{"id":"0fdd41c2-99fd-4a07-9194-f0b91af5f49f","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"ac4cdb02-54a9-4c67-834c-f6dc6ff07a5a","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"4e4eb96e-3172-44d5-b3ef-e856aae4f928","subtype":"Chart","type":"Plot"}},"id":"c3fb950a-4e00-4921-a969-51725057aa4d","type":"ResetTool"},{"attributes":{"below":[{"id":"33f226dd-ba71-40f0-bf8a-4f1e43a99440","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"f3fccb1e-32b6-4582-b718-ae451a35e614","type":"LinearAxis"}],"renderers":[{"id":"3db4a7d2-15bd-4e06-8b83-29504e9fd1b4","type":"BoxAnnotation"},{"id":"21e8a6b8-dc36-4899-be5d-dede4a0820cb","type":"GlyphRenderer"},{"id":"828d8abb-a4be-4f5f-93d2-afab813c83b3","type":"GlyphRenderer"},{"id":"438d61c3-bf27-4307-9acb-ded558a2d2a6","type":"GlyphRenderer"},{"id":"8420fbc9-bc3e-4f52-8fec-08a4da4eb580","type":"GlyphRenderer"},{"id":"2e3ee50c-57b4-45ec-902a-574b90bfcda0","type":"GlyphRenderer"},{"id":"ac4cdb02-54a9-4c67-834c-f6dc6ff07a5a","type":"GlyphRenderer"},{"id":"3fd8b38c-55b0-47ca-b877-9999d14789eb","type":"GlyphRenderer"},{"id":"2b87dd0b-847c-40dc-b57e-63f4b47fb319","type":"GlyphRenderer"},{"id":"5d505474-2dd9-4b82-9b02-c8bc9f51cdc8","type":"Legend"},{"id":"33f226dd-ba71-40f0-bf8a-4f1e43a99440","type":"LinearAxis"},{"id":"f3fccb1e-32b6-4582-b718-ae451a35e614","type":"LinearAxis ...

# %% [markdown]
# ### Controlling the number of bins
#
# By default, Bokeh makes histograms with 10 bins. By controlling the bins parameter of the Histogram() function, you can adjust the number of bins.
#
# In this exercise, you'll plot the 'female_literacy' column of df with 40 bins.

# %%
# Import Histogram, output_file, and show from bokeh.charts
from bokeh.charts import Histogram, output_file, show

# Make the Histogram: p
p = Histogram(df, 'female_literacy', title='Female Literacy', bins=40)

# Set axis labels
p.xaxis.axis_label = 'Female Literacy (% population)'
p.yaxis.axis_label = 'Number of Countries'

# Specify the name of the output_file and show the result
output_file('histogram.html')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f6a1c8e8-f012-4e96-9999-c18c7fa10ee9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f6a1c8e8-f012-4e96-9999-c18c7fa10ee9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f6a1c8e8-f012-4e96-9999-c18c7fa10ee9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f6a1c8e8-f012-4e96-9999-c18c7fa10ee9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"da86e159-6be1-440b-935c-87cddbbdeca1":{"roots":{"references":[{"attributes":{"data_source":{"id":"83c39d83-89dd-4233-84e8-23c42d043375","type":"ColumnDataSource"},"glyph":{"id":"50afb3d9-cc60-41e0-9d80-0d94200c9b57","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"38f100ae-e98c-4758-a261-5d779fde6fb2","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e97013ba-523e-4c26-a2d1-05603494bad2","type":"Rect"},{"attributes":{},"id":"5b4c5a56-7740-4890-a164-335022c059f3","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(23.525000, 25.710000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(23.525000, 25.710000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.1850000000000023],"x":["24.6175"],"y":[0.0]}},"id":"16d77232-a5df-411c-887e-831debd4da88","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ce561e31-4ac5-4c8a-a8b0-6d2e4cb3030d","type":"Rect"},{"attributes":{},"id":"f7566806-3211-488d-b918-566e141c3971","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(25.710000, 27.895000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["(25.710000, 27.895000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.1849999999999987],"x":["26.802500000000002"],"y":[0.5]}},"id":"cac4d5ef-32de-4463-8a88-fab7ecc9dc57","type":"ColumnDataSource"},{"attributes":{},"id":"e39489ad-0c90-471c-8e19-003b4aa748af","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"2f6035c4-d970-466d-8a52-dbd709b3030f","subtype":"Chart","type":"Plot"},"ticker":{"id":"5367778c-82e5-4174-b64d-6db00625ac87","type":"BasicTicker"}},"id":"4dda3149-8ca5-4531-970a-6f315acf2e19","type":"Grid"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c2fc09a7-27dc-4213-a15c-e32fe0ac25b9","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(32.265000, 34.450000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(32.265000, 34.450000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.1850000000000023],"x":["33.3575"],"y":[1.0]}},"id":"47b0ae2a-ca26-44fd-a64d-a2bc2d20bab0","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"16d77232-a5df-411c-887e-831debd4da88","type":"ColumnDataSource"},"glyph":{"id":"ce561e31-4ac5-4c8a-a8b0-6d2e4cb3030d","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"ba70b20a-6d35-41ea-95b6-113180622b3d","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c87bd39f-9c6e-43b7-b70a-33d562031d9f","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(27.895000, 30.080000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(27.895000, 30.080000]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.1849999999999 ...

# %% [markdown]
# ### Generating multiple histograms at once
#
# Now, you'll make separate histograms, each with 10 bins for each of the 6 continents.
#
# To do this with Bokeh charts, you need to pass a column name to the the color parameter of the Histogram() function. In this case, the 'Continent' column contains the continent abbreviation that you'll use to group the female literacy values in each of the 6 continents.

# %%
# Import Histogram, output_file, and show from bokeh.charts
from bokeh.charts import Histogram, output_file, show

# Make a Histogram: p
p = Histogram(df, 'female_literacy', title='Female Literacy',
              color='Continent', legend='top_left', bins=10)

# Set axis labels
p.xaxis.axis_label = 'Female Literacy (% population)'
p.yaxis.axis_label = 'Number of Countries'

# Specify the name of the output_file and show the result
output_file('hist_bins.html')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="25a081d9-c5ca-436f-b0f2-b3b48374e4c7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("25a081d9-c5ca-436f-b0f2-b3b48374e4c7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("25a081d9-c5ca-436f-b0f2-b3b48374e4c7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '25a081d9-c5ca-436f-b0f2-b3b48374e4c7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"69a59f87-1993-4820-a2d5-9e649c29947d":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(97.160000, 97.870000]"],"color":["#407ee7"],"fill_alpha":[0.6],"height":[1.0],"label":["(97.160000, 97.870000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.710000000000008],"x":["97.515"],"y":[0.5]}},"id":"56992152-7713-4d6e-b3ac-a86689c649f8","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"9f08ce70-d393-4cd0-afff-580bc970382d","type":"ColumnDataSource"},"glyph":{"id":"1652e534-d84e-4e2a-a80e-e03d4b8354b7","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"b6954c4c-9de1-4dca-bbf7-12b769516558","type":"GlyphRenderer"},{"attributes":{},"id":"55ac548f-5a58-4215-b61b-443409215cdf","type":"ToolEvents"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1652e534-d84e-4e2a-a80e-e03d4b8354b7","type":"Rect"},{"attributes":{"data_source":{"id":"56992152-7713-4d6e-b3ac-a86689c649f8","type":"ColumnDataSource"},"glyph":{"id":"eeb88cb0-ee3a-478f-9ab1-227cb413fa6c","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"5c31a482-7332-4271-9f30-980c8d08d020","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(97.870000, 98.580000]"],"color":["#407ee7"],"fill_alpha":[0.6],"height":[3.0],"label":["(97.870000, 98.580000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.7099999999999937],"x":["98.225"],"y":[1.5]}},"id":"9f08ce70-d393-4cd0-afff-580bc970382d","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(95.030000, 95.740000]"],"color":["#407ee7"],"fill_alpha":[0.6],"height":[1.0],"label":["(95.030000, 95.740000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.710000000000008],"x":["95.38499999999999"],"y":[0.5]}},"id":"ec4d53e9-f77f-4be4-8cd5-9c444461886f","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"eeb88cb0-ee3a-478f-9ab1-227cb413fa6c","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"94281b77-eb88-4c33-91cd-82bc6888c858","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(74.920000, 78.030000]"],"color":["#df5320"],"fill_alpha":[0.6],"height":[1.0],"label":["(74.920000, 78.030000]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.1099999999999994],"x":["76.475"],"y":[0.5]}},"id":"1a529e30-21d5-4cb3-b47e-1938167b0cf8","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cd84f190-1dc3-4705-88db-1bf8d6673ea2","type":"Rect"},{"attributes":{"data_source":{"id":"8356f3f2-2077-4de6-b5b5-9adfc3b143ae","type":"ColumnDataSource"},"glyph":{"id":"94281b77-eb88-4c33-91cd-82bc6888c858","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"bcd6824e-46c6-40af-9790-9ef7d34d6f16","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"ec4d53e9-f77f-4be4-8c ...

# %% [markdown]
# ## BoxPlots
#
# ### A basic box plot
#
# In this exercise, you'll make a box plot of female literacy per continent by setting values='female_literacy' and label='Continent' with the BoxPlot() function.

# %%
# Import BoxPlot, output_file, and show from bokeh.charts
from bokeh.charts import BoxPlot, output_file, show
# Make a box plot: p
p = BoxPlot(df, values='female_literacy', label='Continent',
            title='Female Literacy (grouped by Continent)', legend='bottom_right')

# Set the y axis label
p.yaxis.axis_label = 'Female literacy (%population)'

# Specify the name of the output_file and show the result
output_file('boxplot.html')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0931c029-ee20-4710-9830-9b8fd0e0d442"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0931c029-ee20-4710-9830-9b8fd0e0d442");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0931c029-ee20-4710-9830-9b8fd0e0d442");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0931c029-ee20-4710-9830-9b8fd0e0d442' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"505fed60-daae-472b-8abc-0b6d722afad7":{"roots":{"references":[{"attributes":{},"id":"718c9a76-8911-4fc3-b82b-cbc00dbefdd6","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Continent":["EUR","EUR"],"chart_index":[{"Continent":"EUR"},{"Continent":"EUR"}],"x_values":["EUR:0.5","EUR:0.5"],"y_values":{"__ndarray__":"mpmZmZk5V0AAAAAAAGBXQA==","dtype":"float64","shape":[2]}}},"id":"e7c9e1ba-d552-4f03-94c6-704339ed220c","type":"ColumnDataSource"},{"attributes":{},"id":"c94a2f0b-eca6-41e3-949f-624b3343dc42","type":"CategoricalTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":
# ### Color different groups differently
#
# Like in the Histogram() function, you can use the color parameter of the BoxPlot() function to color the box plot of each continent separately.
#
# In this exercise, you'll distinguish between the six continents by setting set the color parameter of the BoxPlot() function to 'Continent'.

# %%
# Import BoxPlot, output_file, and show
from bokeh.charts import BoxPlot, output_file, show

# Make a box plot: p
p = BoxPlot(df, values='female_literacy', label='Continent', color='Continent',
            title='Female Literacy (grouped by Continent)', legend='bottom_right')

# Set y-axis label
p.yaxis.axis_label = 'Female literacy (% population)'

# Specify the name of the output_file and show the result
output_file('boxplot.html')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cf75591d-3fcc-45b1-a649-cb8c98dd877b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("cf75591d-3fcc-45b1-a649-cb8c98dd877b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cf75591d-3fcc-45b1-a649-cb8c98dd877b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cf75591d-3fcc-45b1-a649-cb8c98dd877b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ee6a6515-892f-400e-a68d-ce692fafb50f":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e3aee328-4b1c-42f2-a776-37465e2e4cf8","type":"PanTool"},{"id":"2d25ed95-6984-4610-aaae-345858fe0037","type":"WheelZoomTool"},{"id":"9366985e-2bac-4844-a41c-5dea2121ecaf","type":"BoxZoomTool"},{"id":"f5e3127e-82ff-4ddf-878f-b07333a430f5","type":"SaveTool"},{"id":"a5d4235f-7f3b-49ac-a567-493145897204","type":"ResetTool"},{"id":"8c0bf043-969a-4607-8f9b-761977a65116","type":"HelpTool"}]},"id":"b6070db4-720c-4100-885d-5ec17efca602","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"69983849-d05e-4ca2-89df-f28a91703538","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Continent":["AF"],"chart_index":[{"Continent":"AF"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[19.699999999999996],"label":[{"Continent":"AF"}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":["AF"],"y":[69.45]}},"id":"2a9c75ff-fc28-4f56-9f4e-278e6b01bf69","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"a70f3bfc-d48f-426e-a198-180a6ba156b2","type":"ColumnDataSource"},"glyph":{"id":"69983849-d05e-4ca2-89df-f28a91703538","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"3bdcbcc4-e84b-47c0-89b1-5f1c4546676f","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"d0347c81-f369-440f-ae3e-57e8a96d4e27","type":"ColumnDataSource"},"glyph":{"id":"734a7171-4470-448f-840a-6a5066a5ced5","type":"Segment"},"hover_glyph":null,"muted_glyph":null},"id":"15301743-b88c-40fe-9575-7381733b359b","type":"GlyphRenderer"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"12b772f7-48da-4ec4-81c8-06067f09bf24","type":"Segment"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Continent":["LAT"],"chart_index":[{"Continent":"LAT"}],"x_values":["LAT:0.5"],"y_values":{"__ndarray__":"zczMzMwsUUA=","dtype":"float64","shape":[1]}}},"id":"a70f3bfc-d48f-426e-a198-180a6ba156b2","type":"ColumnDataSource"},{"attributes":{"label":{"value":"LAT"},"renderers":[{"id":"a595de67-3892-40e1-add4-484bbd71f192","type":"GlyphRenderer"},{"id":"3e317094-88a8-4f5d-9b8e-1d0dc229a216","type":"GlyphRenderer"},{"id":"3bdcbcc4-e84b-47c0-89b1-5f1c4546676f","type":"GlyphRenderer"},{"id":"fc45b5ec-9c07-49cc-bd59-2b72fe994cf3","type":"GlyphRenderer"}]},"id":"44dad870-5122-4e4f-a743-f209baeecc22","type":"LegendItem"},{"attributes":{"label":{"value":"OCE"},"renderers":[{"id":"42966e28-efde-4eec-b5ff-7496a09251f9","type":"GlyphRenderer"},{"id":"4ea08bff-b2bd-4659-b394-146a7c5d616f","type":"GlyphRenderer"},{"id":"52fa275c-a74d-4234-83b6-35a88826310c","type":"GlyphRenderer"}]},"id":"8716efd1-c89b-4dc9-b449-32223fc3262f","type":"LegendItem"},{"attributes":{"label":{"value":"AF"},"renderers":[{"id":"b9a5a5b8-64a8-47bc-af57-965e284a0173","type":"GlyphRenderer"},{"id":"99947b08-64fa-40e5-b8fc-1241c0c247a4","type":"GlyphRenderer"},{"id":"b8c4b1bb-8c92-4dac-af65-7f6d836e330d","type":"GlyphRenderer"}]},"id":"a6bdc3d6-718b-47b9-be2b-b0ade2580066","type":"LegendItem"},{"attributes":{"axis_label":"Continent","formatter":{"id":"b985951c-e509-47c0-954d-614fe082318d","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"18cbe198-ff26-4d2c-864f-2ea3e2ec20be","subtype":"Chart","type":"Plot"},"ticker":{"id":"a8c3c483-fc87-477d-9e25-6778b3f08fa6","type":"CategoricalTicker"}},"id":"8dee60ac-75e8-4c31-bef6-8429efc60a2d","type":"CategoricalAxis"},{"attributes":{"plot":null,"text":"Female Literacy (grouped by Continent)"},"id":"a66e1314-5ab6-4a92-9206-6c0a2ea8a958","type":"Title"},{"attributes":{"bottom_units":"sc ...

# %% [markdown]
# ## Scatter
#
# ### A basic scatter plot
#
# In this exercise, you'll make a simple scatter plot of female literacy on the y axis and population on x axis. The dataset you have been working with has been pre-loaded into a DataFrame called df.

# %%
# Import Scatter, output_file, and show from bokeh.charts
from bokeh.charts import Scatter, output_file, show

# Make a scatter plot: p
p = Scatter(df, x='population', y='female_literacy',
            title='Female Literacy vs Population')

# Set the x-axis label
p.xaxis.axis_label = 'population'

# Set the y-axis label
p.yaxis.axis_label = 'female literacy'

# Specify the name of the output_file and show the result
output_file('scatterplot.html')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4a3d8d1d-2c5d-4f18-99ca-a6df698cb555"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4a3d8d1d-2c5d-4f18-99ca-a6df698cb555");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4a3d8d1d-2c5d-4f18-99ca-a6df698cb555");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4a3d8d1d-2c5d-4f18-99ca-a6df698cb555' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"615a7037-3b20-44a8-93fd-9606b3db4aa3":{"roots":{"references":[{"attributes":{"plot":{"id":"3ce9e83c-197b-4d60-876e-f25c49cacada","subtype":"Chart","type":"Plot"}},"id":"db52c2bd-eef2-49ab-86b4-04b468b05bd6","type":"PanTool"},{"attributes":{},"id":"19f15f2f-e421-4642-8977-c120a0bfbeff","type":"BasicTicker"},{"attributes":{},"id":"e1dab4a4-9cfc-48a3-bdcc-68ea362eba74","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7477ca76-5fe0-475b-a672-10d190f66c36","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"62889979-be41-4771-a00e-dd30bfa7b1b0","type":"LinearAxis"}],"css_classes":null,"left":[{"id":
# %% [markdown]
# ### Using colors to group data
#
# Just like you've seen with other Bokeh charts, you can use the color parameter in the Scatter() function to color each circle by its 'Continent' in the plot of Female Literacy vs Population.
#
# Once again, the DataFrame has been pre-loaded as df.

# %%
# Import Scatter, output_file, and show from bokeh.charts
from bokeh.charts import Scatter, output_file, show

# Make a scatter plot such that each circle is colored by its continent: p
p = Scatter(df, x='population', y='female_literacy', color='Continent',
            title='Female Literacy vs Population',
            legend = 'bottom_right')

# Set x-axis and y-axis labels
p.xaxis.axis_label = 'Population (millions)'
p.yaxis.axis_label = 'Female literacy (% population)'

# Specify the name of the output_file and show the result
output_file('scatterplot.html')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b35e4489-3a62-4206-ba00-13eaa7511d17"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b35e4489-3a62-4206-ba00-13eaa7511d17");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b35e4489-3a62-4206-ba00-13eaa7511d17");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b35e4489-3a62-4206-ba00-13eaa7511d17' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d98ad113-b1c8-48a6-a1ea-4df83326d024":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"6bf04a6e-57c3-418d-bb7a-802095a3434f","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a33accf1-e424-4d4c-9c03-11150ff33186","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"4b9c4fcd-99a8-4e7d-a48d-7f637b29c753","type":"ColumnDataSource"},"glyph":{"id":"e1ac5804-3586-4298-8e11-b2c91d1e645e","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"4ac06847-a825-4c6c-82c2-2f40db69fb55","type":"GlyphRenderer"},{"attributes":{},"id":"656d159d-779d-4349-a02f-fd08dfbf66cf","type":"ToolEvents"},{"attributes":{"plot":{"id":"c8d17879-baa0-4491-a131-420b3838a048","subtype":"Chart","type":"Plot"}},"id":"dcc335b5-2f1f-4bdb-a00a-30044d80e0cb","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Continent":["EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR","EUR"],"chart_index":[{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"},{"Continent":"EUR"}],"x_values":{"__ndarray__":"","dtype":"float64","shape":[36]},"y_values":{"__ndarray__":"","dtype":"float64","shape":[36]}}},"id":"4b9c4fcd-99a8-4e7d-a48d-7f637b29c753","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"7908251c-bc75-4de3-b644-325805329a68","type":"ColumnDataSource"},"glyph":{"id":"6bf04a6e-57c3-418d-bb7a-802095a3434f","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"f4a81ff1-2b5f-4deb-b300-3d3326a22383","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#df5320"},"line_color":{"value":"#df5320"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"adc94c51-a94b-47d6-8c71-1c658a5d7b02","type":"Circle"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"Continent":["AF","AF","AF","AF","AF","AF","AF","AF","AF","AF","AF","AF","AF","AF","AF","AF","AF","AF","AF","AF","AF","AF" ...

# %% [markdown]
# ### Using shapes to group data
#
# Like the color parameter, the marker type can be set to a column of categorical data to select a different marker for each value.
#
# Here you'll plot Female Literacy vs Population and set a different marker for each of the 6 continents using the marker parameter of the Scatter() function. As before, the DataFrame has been pre-loaded as df.

# %%
# Import Scatter, output_file, and show from bokeh.charts
from bokeh.charts import Scatter, output_file, show

# Make a scatter plot such that each continent has a different marker type: p
p = Scatter(df, x='population', y='female_literacy', 
            color='Continent', marker='Continent',
            title='Female Literacy vs Population',
            legend='bottom_right')

# Set x-axis and y-axis labels
p.xaxis.axis_label = 'Population (millions)'
p.yaxis.axis_label = 'Female literacy (% population)'

# Specify the name of the output_file and show the result
output_file('scatterplot.html')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id